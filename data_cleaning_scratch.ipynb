# %%
import pandas as pd
import numpy as np
import surprise
from surprise.prediction_algorithms import *
import datetime as dt

# %%
# Out:
#   Cell In[31], line 1
#     python -m ipykernel install --user --name=capstone
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # GoodReads Data

# %%
ratings = pd.read_csv('data/ratings.csv')
toread = pd.read_csv('data/to_read.csv')
books = pd.read_csv('data/books.csv')
tags = pd.read_csv('data/tags.csv')
booktags = pd.read_csv('data/book_tags.csv')
gr100k = pd.read_csv('data/GoodReads_100k_books.csv')

# %%
gr100k.head()
# Out:
#                              author bookformat  \
# 0              Laurence M. Hauptman  Hardcover
# 1  Charlotte Fiell,Emmanuelle Dirix  Paperback
# 2                     Andy Anderson  Paperback
# 3              Carlotta R. Anderson  Hardcover
# 4                     Jean Leveille        NaN
#
#                                                 desc  \
# 0  Reveals that several hundred thousand Indians ...
# 1  Fashion Sourcebook - 1920s is the first book i...
# 2  The seminal history and analysis of the Hungar...
# 3  "All-American Anarchist" chronicles the life a...
# 4  Aujourdâ€™hui, lâ€™oiseau nous invite Ã  sa ta...
#
#                                                genre  \
# 0  History,Military History,Civil War,American Hi...
# 1          Couture,Fashion,Historical,Art,Nonfiction
# 2                                   Politics,History
# 3                                      Labor,History
# 4                                                NaN
#
# ...

# %%
gr100k['link'][100]
# Out:
# 'https://goodreads.com/book/show/1001949.Rogue_Star'

# %%
ratings.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %%
toread.head()
# Out:
#    user_id  book_id
# 0        9        8
# 1       15      398
# 2       15      275
# 3       37     7173
# 4       34      380

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...

# %%
tags.tail()
# Out:
#        tag_id    tag_name
# 34247   34247   Ｃhildrens
# 34248   34248   Ｆａｖｏｒｉｔｅｓ
# 34249   34249       Ｍａｎｇａ
# 34250   34250      ＳＥＲＩＥＳ
# 34251   34251  ｆａｖｏｕｒｉｔｅｓ

# %%
type(tags['tag_name'][1])
# Out:
# str

# %%
tags['tag_name'] = tags['tag_name'].replace(' ', '')
tags['tag_name']
# Out:
# 0                 -
# 1              --1-
# 2             --10-
# 3             --12-
# 4            --122-
#             ...
# 34247     Ｃhildrens
# 34248     Ｆａｖｏｒｉｔｅｓ
# 34249         Ｍａｎｇａ
# 34250        ＳＥＲＩＥＳ
# 34251    ｆａｖｏｕｒｉｔｅｓ
# Name: tag_name, Length: 34252, dtype: object

# %%
booktags.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %% [markdown]
# # Attempting GoodReads Scrape

# %% [markdown]
# # Amazon Kindle Data (Small)

# %%
kindletest = pd.read_json('data/Kindle_Store_5.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 kindletest = pd.read_json('data/Kindle_Store_5.json')
#
# File ~/miniconda3/envs/capstone/lib/python3.11/site-packages/pandas/io/json/_json.py:804, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     802     return json_reader
#     803 else:
# --> 804     return json_reader.read()
#
# File ~/miniconda3/envs/capstone/lib/python3.11/site-packages/pandas/io/json/_json.py:1014, in JsonReader.read(self)
#    1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
# -> 1014     obj = self._get_object_parser(self.data)
#    1015 if self.dtype_backend is not lib.no_default:
# ...

# %%
kindletest
